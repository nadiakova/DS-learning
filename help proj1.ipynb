# %%
str = 'Москва , не готов к переезду, не готов к командировкам'
print(str.split(','))
#print(str.split()[0], str.split()[2])

# Переезд
def relocation(str_city):
    
    # Получим список вида ['Москва ', ' м. Беломорская ', ' не готов к переезду', ' не готов к командировкам']
    splited = str_city.split(',')
    
    # Информация о переезде - элемент с идексом 2, если предыдущий - метро, либо элемент с индексом 1
    if splited[1].find('м.') != -1:
        ind = 2
    else:
        ind = 1
            
    if splited[ind].find('не') == -1:
        return True
    else:
        return False
    
print(relocation(str))
# Out:
# ['Москва ', ' не готов к переезду', ' не готов к командировкам']
# False

# %%
str = 'Опыт работы 1 год 1 месяц  Август 2010 — п...'
print(str.split())
x_str = str.split()

list_years = ['год', 'года', 'лет']
list_months = ['месяц', 'месяца', 'месяцев']
experience = 0

if x_str[3] in list_years:
    experience += int(x_str[2])*12
if x_str[5] in list_months:
    experience += int(x_str[4])
if x_str[3] in list_months:
    experience += int(x_str[2])
    
print(experience)
# Out:
# ['Опыт', 'работы', '1', 'год', '1', 'месяц', 'Август', '2010', '—', 'п...']
# 13

# %%
import plotly.graph_objects as go

import numpy as np

x0 = np.random.randn(500)
# Add 1 to shift the mean of the Gaussian distribution
x1 = np.random.randn(500) + 1

fig = go.Figure()
fig.add_trace(go.Histogram(x=x0))
fig.add_trace(go.Histogram(x=x1))

# Overlay both histograms
fig.update_layout(barmode='overlay')
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

x = ['1970-01-01', '1970-01-01', '1970-02-01', '1970-04-01', '1970-01-02',
     '1972-01-31', '1970-02-13', '1971-04-19']

fig = make_subplots(rows=3, cols=2, column_widths=[0.5, 0.5], row_heights=[0.3, 0.3, 0.3], )

trace0 = go.Histogram(x=x, nbinsx=4)
trace1 = go.Histogram(x=x, nbinsx = 8)
trace2 = go.Histogram(x=x, nbinsx=10)
trace3 = go.Histogram(x=x,
                      xbins=dict(
                      start='1969-11-15',
                      end='1972-03-31',
                      size='M18'), # M18 stands for 18 months
                      autobinx=False,
                     )
trace4 = go.Histogram(x=x,
                      xbins=dict(
                      start='1969-11-15',
                      end='1972-03-31',
                      size='M4'), # 4 months bin size
                      autobinx=False,
                      )
trace5 = go.Histogram(x=x,
                      xbins=dict(
                      start='1969-11-15',
                      end='1972-03-31',
                      size= 'M2'), # 2 months
                      autobinx = False
                      )

fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)
fig.append_trace(trace2, 2, 1)
fig.append_trace(trace3, 2, 2)
fig.append_trace(trace4, 3, 1)
fig.append_trace(trace5, 3, 2)
fig.update_layout(height = 700, width = 700)

fig.show()
